# %% [markdown]
# 介绍了opencv中的阈值化操作

# %% [markdown]
# #### 简单阈值cv2.threshhold()

# %% [markdown]
# 像素值高于某个阈值时候，赋值一个新值。其常见的策略包括：
# 1. cv2.THRESH_BINARY
# 2. cv2.THRESH_BINARY_INV
# 3. cv2.THRESH_TRUNC
# 4. cv2.THRESH_TOZERO
# 5. cv2.THRESH_TOZERO_INV
# ![image.png](attachment:image.png)

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./images/sai.jpeg') 
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  # 转化为灰度信息
plt.imshow(img, cmap=plt.cm.gray)
plt.axis('off')
plt.show()

# %%
ret,thresh1=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2=cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV) 
ret,thresh3=cv2.threshold(img,127,255,cv2.THRESH_TRUNC) 
ret,thresh4=cv2.threshold(img,127,255,cv2.THRESH_TOZERO) 
ret,thresh5=cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

# %%
titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV'] 
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.imshow(images[i], cmap=plt.cm.gray)
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# #### 自适应式阈值

# %% [markdown]
# cv2.threshhold()为全局阈值，整幅图像采用同一个数作为阈值。在诸如同一幅图像上的不同部分的具有不同亮度时， 这些情况下我们需要采用自适应阈值。此时的阈值是根据图像上的 每一个小区域计算与其对应的阈值。因此在同一幅图像上的不同区域采用的是 不同的阈值

# %%
"""
adaptiveThreshold(src, maxValue, adaptiveMethod, thresholdType, blockSize, C[, dst]) -> dst
maxValue, 对超过阈值像素值的替代值
adaptiveMethod： 指定计算阈值的方法，cv2.ADPTIVE_THRESH_MEAN_C：阈值取自相邻区域的平均值；cv2.ADPTIVE_THRESH_GAUSSIAN_C：阈值取值相邻区域 的加权和，权重为一个高斯窗口。
thresholdType: 同cv2.threshhold中的策略
blockSize：领域大小
C：一个常数，阈值就等于的平均值或者加权平均值减去这个常数。
"""
print()

# %%
img = cv2.imread('./images/sai.jpeg', 0)

# 普通threshold
