# %% [markdown]
# 介绍matplotlib的参数配置

# %% [markdown]
# #### 方法一：安装级配置文件

# %% [markdown]
# 在python的site-packages目录下。但会随着matplotlib的重新安装会被覆盖，所以不推荐。

# %% [markdown]
# #### 方法二：用户级的配置文件

# %%
import matplotlib as mpl
print(mpl.get_configdir())
# Out:
# /Users/guofei/.matplotlib

# %% [markdown]
# #### 方法三：当前工作目录

# %%
import matplotlib as mpl

# 1.可以通过修改mpl.rcParams字典
# 2.可以在mpl.rc()函数中定义
# Out:
# <function rcdefaults at 0x110a4b0d0>

# %%
import matplotlib.pyplot as plt
import numpy as np
t = np.arange(0.0, 1.0, 0.01)
s = np.sin(2*np.pi*t)

# 第一种配置
plt.rcParams['lines.color'] = 'g'
plt.rcParams['lines.linewidth'] = '2'
plt.plot(t,s)

# %%
# 第二种配置
plt.rcParams['lines.color'] = 'r'
plt.rcParams['lines.linewidth'] = '3'
plt.plot(t,s) 
plt.show()
