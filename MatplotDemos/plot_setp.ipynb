# %% [markdown]
# setp提供了一个为各类artist快速设置属性的方法

# %%
# 公司销售数据
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
# %matplotlib inline

# %%
data = {'Barton LLC': 109438.50,
        'Frami, Hills and Schmidt': 103569.59,
        'Fritsch, Russel and Anderson': 112214.71,
        'Jerde-Hilpert': 112591.43,
        'Keeling LLC': 100934.30,
        'Koepp Ltd': 103660.54,
        'Kulas Inc': 137351.96,
        'Trantow-Barrows': 123381.38,
        'White-Trantow': 135841.99,
        'Will LLC': 104437.60}
group_data = list(data.values())
group_names = list(data.keys())
group_mean = np.mean(group_data)

# %% [markdown]
# 绘制一张简单的图，然后根据布局或样式上的不足进行修改

# %%
# 发现坐标轴刻度显示不美观
fig, ax = plt.subplots(figsize=(6,4))
ax.barh(group_names, group_data)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(6,4))
ax.barh(group_names, group_data)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# #### 使用样式进行控制

# %%
plt.style.use('fivethirtyeight')
fig, ax = plt.subplots(figsize=(6,4))
ax.barh(group_names, group_data)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# #### 通过setp获得artist对象，进行设置

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()   # 获得xticklabels对象
plt.setp(labels, rotation=45, horizontalalignment='right')  # 通过setp进行属性配置

ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
plt.show()

# %% [markdown]
# #### 通过Formatter对象控制ticks样式

# %%
from matplotlib.ticker import FuncFormatter
def currency(x, pos):
    """The two args are the value and tick position"""
    if x >= 1e6:
        s = '${:1.1f}M'.format(x*1e-6)
    else:
        s = '${:1.0f}K'.format(x*1e-3)
    return s

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax.barh(group_names, group_data)
labels = ax.get_xticklabels()   # 获得xticklabels对象
plt.setp(labels, rotation=45, horizontalalignment='right')  # 通过setp进行属性配置

ax.xaxis.set_major_formatter(FuncFormatter(currency))

ax.set(xlim=[-10000, 140000], xlabel='Total Revenue', ylabel='Company',
       title='Company Revenue')
plt.show()
