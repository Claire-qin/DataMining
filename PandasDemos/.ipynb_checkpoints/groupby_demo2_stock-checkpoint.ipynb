# %% [markdown]
# 利用股票数据展示pandas的分组操作

# %% [markdown]
# groupby函数操作的整个流程分为：（1）拆分数据，（2）应用函数，（3）汇总计算结果

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
# 载入数据
df = pd.read_csv('./srcdata/stocks_20170930.csv', dtype={'ticker': str, 'holdingTicker':str,}, encoding='GBK')

# %%
"""
ticker:基金代号
holdingTicker：前10大持仓的股票代码
marketValue：股票市值
industryName1：股票所属产业
"""
df = df[['ticker', 'holdingTicker', 'marketValue', 'industryName1']]
df.head()
# Out:
#    ticker holdingTicker   marketValue industryName1
# 0  000001        002236  2.374015e+08            电子
# 1  000001        000568  2.162791e+08          食品饮料
# 2  000001        300156  1.603200e+08          公用事业
# 3  000001        603799  1.538800e+08          有色金属
# 4  000001        600056  1.519638e+08          医药生物

# %% [markdown]
# 1.分组后统计数量：基金的持股数量

# %%
# 统计整个df在进行ticker字段分组后的数量
df.groupby('ticker').count().tail()
# Out:
#         holdingTicker  marketValue  industryName1
# ticker
# 740101             10           10             10
# 750001             10           10             10
# 750005             10           10             10
# 762001             10           10             10
# 770001             10           10             10

# %%
# 统计holdingTicker在进行ticker字段分组后的数量
df[['holdingTicker']].groupby(df['ticker']).count().tail()
# Out:
#         holdingTicker
# ticker
# 740101             10
# 750001             10
# 750005             10
# 762001             10
# 770001             10

# %% [markdown]
# 2.分组后根据根据统计量进行排序：基金持股所属产业的数量

# %%
df[['holdingTicker']].groupby(df['industryName1']).count().sort_values('holdingTicker', ascending=False).head()
# Out:
#                holdingTicker
# industryName1
# 银行                      4666
# 电子                      3850
# 食品饮料                    3539
# 非银金融                    3306
# 医药生物                    2950

# %%
df[['marketValue']].groupby(df['ticker']).sum().sort_values('marketValue', ascending=False).head()
# Out:
#          marketValue
# ticker
# 510050  1.818564e+10
# 001683  9.222674e+09
# 001772  7.983531e+09
# 150201  7.650096e+09
# 150200  7.650096e+09

# %% [markdown]
# 3.对分组后的某组数据进行自定义的聚合操作

# %% [markdown]
# 3.1 每个基金持股的个股市值差别

# %%
# 自定义一个函数进行聚合操作
def t_range(arr):
     return arr.max() - arr.min()

# 'marketValue'字段根据'ticker'分组后再对每个'ticker'组内的'marketValue'进行聚合操作
df[['marketValue']].groupby(df['ticker']).agg(t_range).head()
# Out:
#          marketValue
# ticker
# 000001  1.349458e+08
# 000003  1.820900e+06
# 000004  1.820900e+06
# 000005  0.000000e+00
# 000007  7.454000e+05

# %% [markdown]
# 3.2 每个基金持股的个股市值最大值、最小值和差别

# %%
# 对同一组数据进行多种聚合操作
df[['marketValue']].groupby(df['ticker']).agg(['sum', 'max', t_range]).head()
# Out:
#          marketValue
#                  sum           max       t_range
# ticker
# 000001  1.517243e+09  2.374015e+08  1.349458e+08
# 000003  5.342707e+06  1.978000e+06  1.820900e+06
# 000004  5.342707e+06  1.978000e+06  1.820900e+06
# 000005  1.277144e+06  1.277144e+06  0.000000e+00
# 000007  8.266880e+06  1.287000e+06  7.454000e+05

# %% [markdown]
# 4.对分组后的多组数据分别进行聚合操作

# %%
df[['marketValue', 'industryName1']].groupby(df['ticker']).agg ({'marketValue':[t_range, 'max'],  'industryName1':['count']}).head()
# Out:
#          marketValue               industryName1
#              t_range           max         count
# ticker
# 000001  1.349458e+08  2.374015e+08            10
# 000003  1.820900e+06  1.978000e+06             4
# 000004  1.820900e+06  1.978000e+06             4
# 000005  0.000000e+00  1.277144e+06             1
# 000007  7.454000e+05  1.287000e+06            10

# %% [markdown]
# 5.统计每只基金持有的前5股票

# %%
import numpy as np
df.groupby(df['ticker']).apply(lambda x: x.sort_values(by='marketValue')[::-3]).head(6)
# Out:
#            ticker holdingTicker   marketValue industryName1
# ticker
# 000001 0   000001        002236  2.374015e+08            电子
#        3   000001        603799  1.538800e+08          有色金属
#        6   000001        000858  1.317445e+08          食品饮料
#        9   000001        600779  1.024557e+08          食品饮料
# 000003 10  000003        600622  1.978000e+06           房地产
#        13  000003        600060  1.571000e+05          家用电器
